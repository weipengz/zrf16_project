# %%
# %load_ext autoreload
# %autoreload 2
import casperfpga
import helper
import numpy as np
import matplotlib.pyplot as plt

# %%
zrf16 = casperfpga.CasperFpga('192.168.50.64')
zrf16.is_connected()
# Out:
# True

# %%
zrf16.upload_to_ram_and_program('rfdc_full.fpg')
zrf16.listdev()
# Out:
# ['ram_dac10_enable',
#  'ram_dac10_even',
#  'ram_dac10_odd',
#  'ram_dac11_enable',
#  'ram_dac11_even',
#  'ram_dac11_odd',
#  'ram_dac12_enable',
#  'ram_dac12_even',
#  'ram_dac12_odd',
#  'ram_dac13_enable',
#  'ram_dac13_even',
#  'ram_dac13_odd',
#  'ram_dac14_enable',
#  'ram_dac14_even',
#  'ram_dac14_odd',
#  'ram_dac15_enable',
#  'ram_dac15_even',
#  'ram_dac15_odd',
#  'ram_dac16_enable',
#  'ram_dac16_even',
#  'ram_dac16_odd',
#  'ram_dac1_enable',
#  'ram_dac1_even',
#  'ram_dac1_odd',
#  'ram_dac2_enable',
#  'ram_dac2_even',
#  'ram_dac2_odd',
#  'ram_dac3_enable',
#  'ram_dac3_even',
#  'ram_dac3_odd',
#  'ram_dac4_enable',
#  'ram_dac4_even',
#  'ram_dac4_odd',
#  'ram_dac5_enable',
#  'ram_dac5_even',
#  'ram_dac5_odd',
#  'ram_dac6_enable',
#  'ram_dac6_even',
#  'ram_dac6_odd',
#  'ram_dac7_enable',
#  'ram_dac7_even',
#  'ram_dac7_odd',
#  'ram_dac8_enable',
#  'ram_dac8_even',
#  'ram_dac8_odd',
#  'ram_dac9_enable',
#  'ram_dac9_even',
#  'ram_dac9_odd',
#  'rfdc',
#  'snapshot_ctrl',
#  'snapshot_m00_ss_bram',
#  'snapshot_m00_ss_ctrl',
#  'snapshot_m00_ss_status',
#  'snapshot_m10_ss_bram',
#  'snapshot_m10_ss_ctrl',
#  'snapshot_m10_ss_status',
#  'snapshot_m20_ss_bram',
#  'snapshot_m20_ss_ctrl',
#  'snapshot_m20_ss_status',
#  'snapshot_m30_ss_bram',
#  'snapshot_m30_ss_ctrl',
#  'snapshot_m30_ss_status',
#  'snapshot_u1_ss_bram',
#  'snapshot_u1_ss_ctrl',
#  'snapshot_u1_ss_status',
#  'snapshot_u2_ss_bram',
#  'snapshot_u2_ss_ctrl',
#  'snapshot_u2_ss_status',
#  'sys',
#  'sys_board_id',
#  'sys_clkcounter',
#  'sys_rev',
#  'sys_rev_rcs',
#  'sys_scratchpad']

# %%
test_bram = zrf16.sbrams['ram_dac1_odd']

# %%
seq_len = int(test_bram.length_bytes/2)
print(seq_len)
# Out:
# 65536

# %%
from scipy.signal import sawtooth
data_seq = np.sin(2*np.pi*2*np.linspace(0,1,seq_len))*255
# data_seq = sawtooth(np.pi*2*np.linspace(0,1,seq_len))*255
data_seq = np.array(data_seq,dtype=int)
# plt.plot(data_seq[:100])
plt.plot(data_seq)
data_seq = data_seq.tolist()
write_data = helper.packet_write_data(data_seq)

# %%
test_bram.write(write_data,True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 32768/32768 [02:21<00:00, 231.21it/s]

# %%
dat = test_bram.read_raw()[0]
read_data = helper.depacket_read_data(dat)
plt.plot(read_data)
# plt.plot(read_data[:100])

# %%
rfdc_zrf16 = zrf16.adcs['rfdc']
rfdc_zrf16.init()
# Out:
# True

# %%
rfdc_zrf16.status()
# Out:
# ADC0: Enabled 1, State: 15 PLL: 0
# ADC1: Enabled 1, State: 15 PLL: 0
# ADC2: Enabled 1, State: 15 PLL: 1
# ADC3: Enabled 1, State: 15 PLL: 0
# True

# %%
xm1, xm2, xm3, xm4 = helper.capture(zrf16)
N = 1024
n = np.arange(0,N)
fig, ax = plt.subplots(1,4,sharey=True,figsize=(16,3))
ax[0].plot(n, np.real(xm1[:N])); ax[0].set_title('Tile 0 Ch.0'); ax[0].grid(True);
ax[1].plot(n, np.real(xm2[:N])); ax[1].set_title('Tile 1 Ch.0'); ax[1].grid(True);
ax[2].plot(n, np.real(xm3[:N])); ax[2].set_title('Tile 2 Ch.0'); ax[2].grid(True);
ax[3].plot(n, np.real(xm4[:N])); ax[3].set_title('Tile 3 Ch.0'); ax[3].grid(True);
plt.tight_layout()

# %%
zrf16.write_int('ram_dac1_enable',1)

# %%
u_data = helper.capture_u(zrf16)
plt.plot(u_data[0][:seq_len])
plt.plot(u_data[1][:seq_len])
plt.legend(['u1','u2'])
